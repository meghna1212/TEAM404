# %% [markdown]
# # CV Dataset Creation using Parsed and Summarized CVs

# %% [markdown]
# Through this module, we'll be using the NLP model that we created in the previous module to create a dataset for all the CVs that our system will receive thorough the candidates which will further be ranked according to the requirements of the Recruiter.

# %%
import spacy
import pickle
import random
import pandas as pd

# %%
Name=[]
Location=[]
Email_Address=[]
Degree=[]
College_Name=[]
Skills=[]
Designation=[]

# %%
train_data = pickle.load(open('C:\\Users\\Meghna\\Desktop\\CV Ranking\\train_data.pkl','rb'))

# %%
nlp_model = spacy.load('C:\\Users\\Meghna\\Desktop\\CV Ranking\\nlp_model')

# %%
for x in range(200):
    doc = nlp_model(train_data[x][0])
    for ent in doc.ents:

        if(ent.label_ == 'Name'):
            Name.append(ent.text)
        elif(ent.label_ == 'Location'):
            Location.append(ent.text)
        elif(ent.label_ == 'Email Address'):
            Email_Address.append(ent.text)
        elif(ent.label_ == 'Degree'):
            Degree.append(ent.text)
        elif(ent.label_ == 'College Name'):
            College_Name.append(ent.text)
        elif(ent.label_ == 'Skills'):
            Skills.append(ent.text)
        elif(ent.label_ == 'Designation'):
            Designation.append(ent.text)

# %%
df = pd.DataFrame(list(zip(Name,Location,Email_Address,Degree,College_Name,Skills,Designation)),
                  columns =['Name', 'Location','Email Address','Degree','College Name','Skills','Applied Role'])
df
# Out:
#                    Name    Location  \
# 0          Govardhana K   Bengaluru
# 1    Harini Komaravelli     Oracle,
# 2       Hartej Kathuria   Hyderabad
# 3       Ijas Nizamuddin   Hyderabad
# 4      Imgeeyaul Ansari   Hyderabad
# ..                  ...         ...
# 144           Puneeth R    hyderbad
# 145      Kandrapu Reddy    hyderbad
# 146     Vineeth Vijayan     Chennai
# 147        Rahul Tayade  Chandigarh
# 148   Debasish Dasgupta  Chandigarh
#
#                                          Email Address  \
# 0        indeed.com/r/Hartej-Kathuria/04181c5962a4af19
# 1       indeed.com/r/Imgeeyaul-Ansari/a7be1cc43a434ac4
# 2          indeed.com/r/Jitendra-Babu/bc3ea69a183395ed
# 3    indeed.com/r/Jyotirbindu- Patnaik/77e3ceda47fb...
# 4        indeed.com/r/Karthihayini- C/627254c443836b3c
# ..                                                 ...
# 144            indeed.com/r/Sridevi-H/63703b24aaaa54e4
# 145        indeed.com/r/Raktim-Podder/32472fc557546084
# 146           indeed.com/r/Pavithra-M/26f392ec8251143b
# 147      indeed.com/r/shrikant-desai/ cc6430615ce4d44a
# 148          indeed.com/r/Kiran-Kumar/7e76e7a9e62e7ee5
#
#                                                 Degree  \
# 0                  B.E in Computer Science Engineering
# 1                                                  MCA
# 2                            B.Sc. in Computer Science
# 3                        Birla Institute Of Technology
# 4    Bachelor of Enginerring in Information Technology
# ..                                                 ...
# 144                                       B.B.A in UIT
# 145                                                BSc
# 146                                                MSC
# 147                                              B.C.A
# 148                                              Btech
#
#                                     College Name  \
# 0                Adithya Institute of Technology
# 1                                   Test Analyst
# 2                             Osmania University
# 3                             Osmania University
# 4              University College Of Engineering
# ..                                           ...
# 144  Member of Discipline Committee in ALGORYTHM
# 145                          Chitkara University
# 146                   PES College of Engineering
# 147    Orange City Hospital & Research Institute
# 148         S.N.G College, Bharathiar University
#
#                                                 Skills  \
# 0    Functional Testing, Blue Prism, Qtp  ADDITIONA...
# 1    Python (2 years), SQL. (1 year), NOSQL (1 year...
# 2    :    Languages: Core Java Front end/GUI Tools ...
# 3                                           SQL Oracle
# 4                                      ITIL foundation
# ..                                                 ...
# 144             TALLY MICROSOFT DYNAMIC OPARATER MICIT
# 145  EXCEL (Less than 1 year), OUTLOOK (Less than 1...
# 146  SAP HANA (4 years), SAP UI5/Fiori (4 years), A...
# 147  AUDITING (Less than 1 year), CFA (Less than 1 ...
# 148  SKILLS  Splunk, Network Security, Arc sight (2...
#
#                                     Applied Role
# 0                       Senior Software Engineer
# 1                       Senior Software Engineer
# 2                           Associate Consultant
# 3                                   Test Analyst
# 4                                     QA Analyst
# ..                                           ...
# 144                    Technical Project Manager
# 145  Arabic Language supporter (Content Analyst)
# 146                    Chief Coordinator of LEAR
# 147                        Technical Architect &
# 148                          Technical Architect
#
# [149 rows x 7 columns]

# %% [markdown]
# Now, we'll be saving this dataset to our local disk as follows:

# %%
#Saving the dataframe
df.to_csv('CV_DataFrame.csv')
